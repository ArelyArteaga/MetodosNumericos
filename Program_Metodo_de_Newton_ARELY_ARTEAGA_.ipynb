# %%
#Program Newton's Method
#To obtain a solution to f(x)=0 given the differentiable function f and an initial approximation p0
#ARELY ARTEAGA
#Program Newton's method reproducing the results of page 69


# Defining Function (METHOD IN ENGLISH)
def f(x):
    return x**3 - 5*x - 9

# Defining derivative of function
def g(x):
    return 3*x**2 - 5

# Implementing Newton Raphson Method

def newtonRaphson(x0,e,N):
    print('\n\n*** NEWTON RAPHSON METHOD IMPLEMENTATION ***')
    step = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Divide by zero error!')
            break

        x1 = x0 - f(x0)/g(x0)
        print('Iteration-%d, x1 = %0.6f and f(x1) = %0.6f' % (step, x1, f(x1)))
        x0 = x1
        step = step + 1

        if step > N:
            flag = 0
            break

        condition = abs(f(x1)) > e

    if flag==1:
        print('\nRequired root is: %0.8f' % x1)
    else:
        print('\nNot Convergent.')


# Input Section
x0 = input('Enter Guess: ')
e = input('Tolerable Error: ')
N = input('Maximum Step: ')

# Converting x0 and e to float
x0 = float(x0)
e = float(e)

# Converting N to integer
N = int(N)


#Note: You can combine above three section like this
# x0 = float(input('Enter Guess: '))
# e = float(input('Tolerable Error: '))
# N = int(input('Maximum Step: '))

# Starting Newton Raphson Method
newtonRaphson(x0,e,N)
# Out:
# Enter Guess: 2
# Tolerable Error: 0.000001
# Maximum Step: 10
#
#
# *** NEWTON RAPHSON METHOD IMPLEMENTATION ***
# Iteration-1, x1 = 3.571429 and f(x1) = 18.696793
# Iteration-2, x1 = 3.009378 and f(x1) = 3.207103
# Iteration-3, x1 = 2.864712 and f(x1) = 0.185915
# Iteration-4, x1 = 2.855236 and f(x1) = 0.000771
# Iteration-5, x1 = 2.855197 and f(x1) = 0.000000
#
# Required root is: 2.85519654

# %% [markdown]
# # MÉTODO DE NEWTON

# %%
#Program Metodo de Newton
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Metodo de Newton reproduciendo los resultados de la pag 69

print('\n\n** Metodo de Newton **')
print('......................................................................')

# Definir funcion
import math
def f(x):
    return math.cos(x) - x

# Definir la derivada de la funcion
def g(x):
    return - (math.sin(x)) - 1

# Implementacion del Metodo de Newton

def newtonRaphson(x0,e,N):
    print('\n\n** Implementacion del Metodo **')
    i = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Error!: No podemos dividir entre cero')
            break

        p = x0 - f(x0)/g(x0)
        print('Iteracion %d: p = %0.6f y f(p) = %0.6f' % (i, p, f(p)))
        x0 = p
        i = i + 1

        if i > N:
            flag = 0
            break

        condition = abs(f(p)) > e

    if flag==1:
        print('\nLa raiz es: p = %0.8f' % p)
    else:
        print('\nNo es Convergente.')


# Seccion de entrada
x0 = input('Aproximacion inicial: p0= ')
e = input('Tolerancia: TOL= ')
N = input('Numero maximo de iteraciones: N0= ')

# Convertir x0 y e en float
x0 = float(x0)
e = float(e)

# Convertir N en integer
N = int(N)


# x0 = float(input('Aproximacion inicial: p0= '))
# e = float(input('Tolerancia: TOL= '))
# N = int(input('Numero maximo de iteraciones: N0= '))

# Iniciar el metodo de Newton
newtonRaphson(x0,e,N)
# Out:
# ** Metodo de Newton **
# ......................................................................
# Aproximacion inicial: p0= 0.785398163
# Tolerancia: TOL= 1E-16
# Numero maximo de iteraciones: N0= 100
#
#
# ** Implementacion del Metodo **
# Iteracion 1: p = 0.739536 y f(p) = -0.000755
# Iteracion 2: p = 0.739085 y f(p) = -0.000000
# Iteracion 3: p = 0.739085 y f(p) = -0.000000
# Iteracion 4: p = 0.739085 y f(p) = 0.000000
#
# La raiz es: p = 0.73908513

# %%
#Program Metodo de Newton
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Metodo de Newton reproduciendo los resultados del ejercicio 5(a)

print('\n\n** Metodo de Newton **')
print('......................................................................')

# Definir funcion
import math
def f(x):
    return pow (x,3) - 2 * pow (x,2) - 5

# Definir la derivada de la funcion
def g(x):
    return 3* pow (x,2) - 4 * x

# Implementacion del Metodo de Newton

def newtonRaphson(x0,e,N):
    print('\n\n** Implementacion del Metodo **')
    i = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Error!: No podemos dividir entre cero')
            break

        p = x0 - f(x0)/g(x0)
        print('Iteracion %d: p = %0.6f y f(p) = %0.6f' % (i, p, f(p)))
        x0 = p
        i = i + 1

        if i > N:
            flag = 0
            break

        condition = abs(f(p)) > e

    if flag==1:
        print('\nLa raiz es: p = %0.8f' % p)
    else:
        print('\nNo es Convergente.')


# Seccion de entrada
x0 = input('Aproximacion inicial: p0= ')
e = input('Tolerancia: TOL= ')
N = input('Numero maximo de iteraciones: N0= ')

# Convertir x0 y e en float
x0 = float(x0)
e = float(e)

# Convertir N en integer
N = int(N)


# x0 = float(input('Aproximacion inicial: p0= '))
# e = float(input('Tolerancia: TOL= '))
# N = int(input('Numero maximo de iteraciones: N0= '))

# Iniciar el metodo de Newton
newtonRaphson(x0,e,N)
# Out:
# ** Metodo de Newton **
# ......................................................................
# Aproximacion inicial: p0= 2
# Tolerancia: TOL= 1e-4
# Numero maximo de iteraciones: N0= 100
#
#
# ** Implementacion del Metodo **
# Iteracion 1: p = 3.250000 y f(p) = 8.203125
# Iteracion 2: p = 2.811037 y f(p) = 1.408754
# Iteracion 3: p = 2.697990 y f(p) = 0.080768
# Iteracion 4: p = 2.690677 y f(p) = 0.000325
# Iteracion 5: p = 2.690647 y f(p) = 0.000000
#
# La raiz es: p = 2.69064745

# %%
#Program Metodo de Newton
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Metodo de Newton 5(b)

print('\n\n** Metodo de Newton **')
print('......................................................................')

# Definir funcion
import math
def f(x):
    return pow (x,3) + 3 * pow (x,2) - 1

# Definir la derivada de la funcion
def g(x):
    return 3* pow (x,2) + 6 * x

# Implementacion del Metodo de Newton

def newtonRaphson(x0,e,N):
    print('\n\n** Implementacion del Metodo **')
    i = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Error!: No podemos dividir entre cero')
            break

        p = x0 - f(x0)/g(x0)
        print('Iteracion %d: p = %0.6f y f(p) = %0.6f' % (i, p, f(p)))
        x0 = p
        i = i + 1

        if i > N:
            flag = 0
            break

        condition = abs(f(p)) > e

    if flag==1:
        print('\nLa raiz es: p = %0.8f' % p)
    else:
        print('\nNo es Convergente.')


# Seccion de entrada
x0 = input('Aproximacion inicial: p0= ')
e = input('Tolerancia: TOL= ')
N = input('Numero maximo de iteraciones: N0= ')

# Convertir x0 y e en float
x0 = float(x0)
e = float(e)

# Convertir N en integer
N = int(N)


# x0 = float(input('Aproximacion inicial: p0= '))
# e = float(input('Tolerancia: TOL= '))
# N = int(input('Numero maximo de iteraciones: N0= '))

# Iniciar el metodo de Newton
newtonRaphson(x0,e,N)
# Out:
# ** Metodo de Newton **
# ......................................................................
# Aproximacion inicial: p0= -3
# Tolerancia: TOL= 1e-4
# Numero maximo de iteraciones: N0= 100
#
#
# ** Implementacion del Metodo **
# Iteracion 1: p = -2.888889 y f(p) = -0.072702
# Iteracion 2: p = -2.879452 y f(p) = -0.000504
# Iteracion 3: p = -2.879385 y f(p) = -0.000000
#
# La raiz es: p = -2.87938524

# %%
#Program Metodo de Newton
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Metodo de Newton 5(c)

print('\n\n** Metodo de Newton **')
print('......................................................................')

# Definir funcion
import math
def f(x):
    return x - (math.cos(x))

# Definir la derivada de la funcion
def g(x):
    return 1 + (math.sin(x))

# Implementacion del Metodo de Newton

def newtonRaphson(x0,e,N):
    print('\n\n** Implementacion del Metodo **')
    i = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Error!: No podemos dividir entre cero')
            break

        p = x0 - f(x0)/g(x0)
        print('Iteracion %d: p = %0.6f y f(p) = %0.6f' % (i, p, f(p)))
        x0 = p
        i = i + 1

        if i > N:
            flag = 0
            break

        condition = abs(f(p)) > e

    if flag==1:
        print('\nLa raiz es: p = %0.8f' % p)
    else:
        print('\nNo es Convergente.')


# Seccion de entrada
x0 = input('Aproximacion inicial: p0= ')
e = input('Tolerancia: TOL= ')
N = input('Numero maximo de iteraciones: N0= ')

# Convertir x0 y e en float
x0 = float(x0)
e = float(e)

# Convertir N en integer
N = int(N)


# x0 = float(input('Aproximacion inicial: p0= '))
# e = float(input('Tolerancia: TOLERANCIA= '))
# N = int(input('Numero maximo de iteraciones: N0= '))

# Iniciar el metodo de Newton
newtonRaphson(x0,e,N)
# Out:
# ** Metodo de Newton **
# ......................................................................
# Aproximacion inicial: p0= 0
# Tolerancia: TOL= 1E-4
# Numero maximo de iteraciones: N0= 100
#
#
# ** Implementacion del Metodo **
# Iteracion 1: p = 1.000000 y f(p) = 0.459698
# Iteracion 2: p = 0.750364 y f(p) = 0.018923
# Iteracion 3: p = 0.739113 y f(p) = 0.000046
#
# La raiz es: p = 0.73911289

# %%
#Program Metodo de Newton
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Metodo de Newton 5(d)

print('\n\n** Metodo de Newton **')
print('......................................................................')

# Definir funcion
import math
def f(x):
    return x - 0.8 - (0.2) * (math.sin(x))

# Definir la derivada de la funcion
def g(x):
    return 1 - ((math.cos(x)))/5

# Implementacion del Metodo de Newton

def newtonRaphson(x0,e,N):
    print('\n\n** Implementacion del Metodo **')
    i = 1
    flag = 1
    condition = True
    while condition:
        if g(x0) == 0.0:
            print('Error!: No podemos dividir entre cero')
            break

        p = x0 - f(x0)/g(x0)
        print('Iteracion %d: p = %0.6f y f(p) = %0.6f' % (i, p, f(p)))
        x0 = p
        i = i + 1

        if i > N:
            flag = 0
            break

        condition = abs(f(p)) > e

    if flag==1:
        print('\nLa raiz es: p = %0.8f' % p)
    else:
        print('\nNo es Convergente.')


# Seccion de entrada
x0 = input('Aproximacion inicial: p0= ')
e = input('Tolerancia: TOL= ')
N = input('Numero maximo de iteraciones: N0= ')

# Convertir x0 y e en float
x0 = float(x0)
e = float(e)

# Convertir N en integer
N = int(N)


# x0 = float(input('Aproximacion inicial: p0= '))
# e = float(input('Tolerancia: TOLERANCIA= '))
# N = int(input('Numero maximo de iteraciones: N0= '))

# Iniciar el metodo de Newton
newtonRaphson(x0,e,N)
# Out:
# ** Metodo de Newton **
# ......................................................................
# Aproximacion inicial: p0= 0
# Tolerancia: TOL= 1e-4
# Numero maximo de iteraciones: N0= 100
#
#
# ** Implementacion del Metodo **
# Iteracion 1: p = 1.000000 y f(p) = 0.031706
# Iteracion 2: p = 0.964453 y f(p) = 0.000106
# Iteracion 3: p = 0.964334 y f(p) = 0.000000
#
# La raiz es: p = 0.96433389

# %% [markdown]
# #MÉTODO DE LA SECANTE

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante del ejemplo 2



# Definiendo la Funcion

def f(x):
    return x**3 - 5*x - 9

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: 2
# Ingresa la Segunda Suposicion: 3
#  Error Tolerable: 0.00001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = 2.785714 and f(x2) = -1.310860
# Iteration-2, x2 = 2.850875 and f(x2) = -0.083923
# Iteration-3, x2 = 2.855332 and f(x2) = 0.002635
# Iteration-4, x2 = 2.855196 and f(x2) = -0.000005
#
#  Required root is: 2.85519628

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante del ejemplo 2



# Definiendo la Funcion
import math
def f(x):
    return (math.cos(x)) - x

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: 0.5
# Ingresa la Segunda Suposicion: 0.785398
#  Error Tolerable: 0.0000000001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = 0.736384 and f(x2) = 0.004518
# Iteration-2, x2 = 0.739058 and f(x2) = 0.000045
# Iteration-3, x2 = 0.739085 and f(x2) = -0.000000
# Iteration-4, x2 = 0.739085 and f(x2) = 0.000000
#
#  Required root is: 0.73908513

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante PROBLEMA 5(a)



# Definiendo la Funcion
import math
def f(x):
    return pow (x,3) - 2 * pow (x,2) - 5

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: 1
# Ingresa la Segunda Suposicion: 4
#  Error Tolerable: 0.0000000001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = 1.545455 and f(x2) = -6.085650
# Iteration-2, x2 = 1.996934 and f(x2) = -5.012225
# Iteration-3, x2 = 4.105063 and f(x2) = 30.473574
# Iteration-4, x2 = 2.294699 and f(x2) = -3.448220
# Iteration-5, x2 = 2.478726 and f(x2) = -2.058665
# Iteration-6, x2 = 2.751368 and f(x2) = 0.687876
# Iteration-7, x2 = 2.683084 and f(x2) = -0.082514
# Iteration-8, x2 = 2.690398 and f(x2) = -0.002731
# Iteration-9, x2 = 2.690648 and f(x2) = 0.000011
# Iteration-10, x2 = 2.690647 and f(x2) = -0.000000
# Iteration-11, x2 = 2.690647 and f(x2) = -0.000000
#
#  Required root is: 2.69064745

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante PROBLEMA 7(b)



# Definiendo la Funcion
import math
def f(x):
    return pow (x,3) + 3 * pow (x,2) - 1

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: -3
# Ingresa la Segunda Suposicion: -2
#  Error Tolerable: 0.0000000001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = -2.750000 and f(x2) = 0.890625
# Iteration-2, x2 = -3.066667 and f(x2) = -1.626963
# Iteration-3, x2 = -2.862024 and f(x2) = 0.130184
# Iteration-4, x2 = -2.877186 and f(x2) = 0.016679
# Iteration-5, x2 = -2.879414 and f(x2) = -0.000218
# Iteration-6, x2 = -2.879385 and f(x2) = 0.000000
# Iteration-7, x2 = -2.879385 and f(x2) = 0.000000
#
#  Required root is: -2.87938524

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante PROBLEMA 7(c)



# Definiendo la Funcion
import math
def f(x):
    return x - (math.cos(x))

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: 0
# Ingresa la Segunda Suposicion: 1.57
#  Error Tolerable: 0.0000000001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = 0.611084 and f(x2) = -0.207942
# Iteration-2, x2 = 0.723286 and f(x2) = -0.026349
# Iteration-3, x2 = 0.739566 and f(x2) = 0.000805
# Iteration-4, x2 = 0.739083 and f(x2) = -0.000003
# Iteration-5, x2 = 0.739085 and f(x2) = -0.000000
# Iteration-6, x2 = 0.739085 and f(x2) = 0.000000
#
#  Required root is: 0.73908513

# %%
#Program Metodo de la Secante
#Para obtener una solucion a f(x)=0 dada la funcion diferenciable f y una aproximacion inicial p0
#ARELY ARTEAGA
#Program Método de la Secante PROBLEMA 7(d)



# Definiendo la Funcion
import math
def f(x):
    return x - 0.8 - (0.2) * (math.sin(x))

# Implementando el Metodo de la Secante

def secant(x0,x1,e,N):
    print('\n\n*** IMPLEMENTACION DEL METODO DE LA SECANTE  ***')
    step = 1
    condition = True
    while condition:
        if f(x0) == f(x1):
            print('Dividir por error cero!')
            break

        x2 = x0 - (x1-x0)*f(x0)/( f(x1) - f(x0) )
        print('Iteration-%d, x2 = %0.6f and f(x2) = %0.6f' % (step, x2, f(x2)))
        x0 = x1
        x1 = x2
        step = step + 1

        if step > N:
            print('No Converge!')
            break

        condition = abs(f(x2)) > e
    print('\n Required root is: %0.8f' % x2)


# Seccion de Entrada
x0 = input('Ingresa la Primera Suposicion: ')
x1 = input('Ingresa la Segunda Suposicion: ')
e = input(' Error Tolerable: ')
N = input('Escalón Máximo (Paso Max): ')

# Conversión de x0 y e a float
x0 = float(x0)
x1 = float(x1)
e = float(e)

# Convertir N en entero
N = int(N)


#Nota: Se Puede combinar las tres secciones anteriores así
# x0 = float(input('Ingresa la Primera Suposicion: '))
# x1 = float(input('Ingresa la Segunda Suposicion: '))
# e = float(input('Error Tolerable: '))
# N = int(input('Escalón Máximo (Paso Max): '))

# EMPEZAR EL MÉTODO DE  SECANTE
secant(x0,x1,e,N)
# Out:
# Ingresa la Primera Suposicion: 0
# Ingresa la Segunda Suposicion: 1.57
#  Error Tolerable: 0.0000000001
# Escalón Máximo (Paso Max): 100
#
#
# *** IMPLEMENTACION DEL METODO DE LA SECANTE  ***
# Iteration-1, x2 = 0.916788 and f(x2) = -0.041942
# Iteration-2, x2 = 0.961559 and f(x2) = -0.002458
# Iteration-3, x2 = 0.964346 and f(x2) = 0.000011
# Iteration-4, x2 = 0.964334 and f(x2) = -0.000000
# Iteration-5, x2 = 0.964334 and f(x2) = -0.000000
#
#  Required root is: 0.96433389

# %% [markdown]
# #MÉTODO DE NEWTON MODIFICADO

# %%
#Program Metodo de NEWTON MODIFICADO
#ARELY ARTEAGA
#Program Método de NEWTON MODIFICADO del ejemplo 2 (PAG 84)

#Ingresemos datos
print('¿Cuál es la aproximación inicial?')
PO=float(input())

print('¿Cuanta tolerancia?')
TOL=float(input())

print('¿Cuantas iteraciones?')
N=int(input())

#Definimos ahora la función, la cual cambia cada que sea necesario
import math
def f(x):
    return  pow(math.e,x) - x - 1

#Definimos derivada
def g(x):
    return pow(math.e,x) - 1

#Definimos la segunda derivada
def h(x):
    return pow(math.e,x)

#Método
i=0
while i<=N:
    P=PO-((f(PO)*g(PO))/((g(PO)**2)-(f(PO)*h(PO))))
#Evaluando
    if abs(P-PO)<TOL:
        print('La aproximación después de',i,'Iteraciones es P=',P)
        break
#Ahora para la siguiente iteración modificamos
    i=i+1
    PO=P
#Obtenemos
    if i<=N:
        print('Después de',i,'Iteraciones el punto obtenido es P=',P)
    else:
        print('El método falló después de',N,'Iteraciones')
# Out:
# ¿Cuál es la aproximación inicial?
# 1
# ¿Cuanta tolerancia?
# 0.0000000001
# ¿Cuantas iteraciones?
# 20
# Después de 1 Iteraciones el punto obtenido es P= -0.23421061355351425
# Después de 2 Iteraciones el punto obtenido es P= -0.00845827991076109
# Después de 3 Iteraciones el punto obtenido es P= -1.1890183808588653e-05
# Después de 4 Iteraciones el punto obtenido es P= -4.218590698935789e-11
# La aproximación después de 4 Iteraciones es P= -4.218590698935789e-11

# %%
#Program Metodo de NEWTON MODIFICADO
#ARELY ARTEAGA
#Program Método de NEWTON MODIFICADO PROBLEMA 2 (a)(PAG 85)

#Ingresemos datos
print('¿Cuál es la aproximación inicial?')
PO=float(input())

print('¿Cuanta tolerancia?')
TOL=float(input())

print('¿Cuantas iteraciones?')
N=int(input())

#Definimos ahora la función, la cual cambia cada que sea necesario
import math
def f(x):
    return  1 - 4 *x * (math.cos(x)) + 2 * pow(x,2) + (math.cos(2 * x))

#Definimos derivada
def g(x):
    return - 2 * (math.sin(2 * x)) + 4 * x * (math.sin(x)) - 4 * (math.cos(x)) + 4 * x

#Definimos la segunda derivada
def h(x):
    return - 4 * (math.cos(2 * x)) + 8 * (math.sin(x)) + 4 * x * (math.cos(x)) + 4

#Método
i=0
while i<=N:
    P=PO-((f(PO)*g(PO))/((g(PO)**2)-(f(PO)*h(PO))))
#Evaluando
    if abs(P-PO)<TOL:
        print('La aproximación después de',i,'Iteraciones es P=',P)
        break
#Ahora para la siguiente iteración modificamos
    i=i+1
    PO=P
#Obtenemos
    if i<=N:
        print('Después de',i,'Iteraciones el punto obtenido es P=',P)
    else:
        print('El método falló después de',N,'Iteraciones')
# Out:
# ¿Cuál es la aproximación inicial?
# 0
# ¿Cuanta tolerancia?
# 0.0000000001
# ¿Cuantas iteraciones?
# 20
# Después de 1 Iteraciones el punto obtenido es P= 0.5
# Después de 2 Iteraciones el punto obtenido es P= 0.7216635041043578
# Después de 3 Iteraciones el punto obtenido es P= 0.7390161853007047
# Después de 4 Iteraciones el punto obtenido es P= 0.7390851321642945
# La aproximación después de 4 Iteraciones es P= 0.7390851321642945

# %%
#Program Metodo de NEWTON MODIFICADO
#ARELY ARTEAGA
#Program Método de NEWTON MODIFICADO PROBLEMA 2 (b)(PAG 85)

#Ingresemos datos
print('¿Aproximación inicial?')
PO=float(input())

print('¿Tolerancia?')
TOL=float(input())

print('¿Cuantas iteraciones?')
N=int(input())

#Definimos ahora la función, la cual cambia cada que sea necesario
import math
def f(x):
    return  pow(x,2) + 6  * pow(x,5) + 9 * pow(x,4) - 2 * pow(x,3)-6  * pow(x,2)+1

#Definimos derivada
def g(x):
    return 30* pow(x,4) + 36* pow(x,3)-6  * pow(x,2)-10 * x

#Definimos la segunda derivada
def h(x):
    return 120 * pow(x,3) + 108 * pow(x,2) - 12 * x - 10

#Método
i=0
while i<=N:
    P=PO-((f(PO)*g(PO))/((g(PO)**2)-(f(PO)*h(PO))))
#Evaluando
    if abs(P-PO)<TOL:
        print('La aproximación después de',i,'Iteraciones es P=',P)
        break
#Ahora para la siguiente iteración modificamos
    i=i+1
    PO=P
#Obtenemos
    if i<=N:
        print('Después de',i,'Iteraciones el punto obtenido es P=',P)
    else:
        print('El método falló después de',N,'Iteraciones')
# Out:
# ¿Aproximación inicial?
# -2.5
# ¿Tolerancia?
# 0.0000000001
# ¿Cuantas iteraciones?
# 100
# Después de 1 Iteraciones el punto obtenido es P= -0.777690250176531
# Después de 2 Iteraciones el punto obtenido es P= -1.8582684631674127
# Después de 3 Iteraciones el punto obtenido es P= -1.023491201497651
# Después de 4 Iteraciones el punto obtenido es P= -0.9161911608968712
# Después de 5 Iteraciones el punto obtenido es P= -0.6091091832313777
# Después de 6 Iteraciones el punto obtenido es P= -0.6229339917102019
# Después de 7 Iteraciones el punto obtenido es P= -0.6509224861803932
# Después de 8 Iteraciones el punto obtenido es P= -0.7114181870168154
# Después de 9 Iteraciones el punto obtenido es P= -0.8988256736049651
# Después de 10 Iteraciones el punto obtenido es P= -0.5394843864733534
# Después de 11 Iteraciones el punto obtenido es P= -0.4742231840372036
# Después de 12 Iteraciones el punto obtenido es P= -0.22605408634511498
# ...

# %%
#Program Metodo de NEWTON MODIFICADO
#ARELY ARTEAGA
#Program Método de NEWTON MODIFICADO PROBLEMA 2 (c)(PAG 85)

#Ingresemos datos
print('¿Cuál es la aproximación inicial?')
PO=float(input())

print('¿Cuanta tolerancia?')
TOL=float(input())

print('¿Cuantas iteraciones?')
N=int(input())

#Definir la funcion
import math
def f(x):
    return  math.sin(3*x) + 3*math.exp(-2*x)*math.sin(x) - 3*math.exp(-x)*math.sin(2*x) - math.exp(-3*x)

#Definir primera derivada
def g(x):
    return 3*math.cos(3*x) + 3*math.exp(-x)*math.sin(2*x) - 6*math.exp(-x)*math.cos(2*x) - 6*math.exp(-2*x)*math.sin(x) + 3*math.exp(-2*x)*math.cos(x) + 3*math.exp(-3*x)

#Definir segunda derivada
def h(x):
    return - math.exp(-3*x)*(9*math.exp(3*x) - 9+math.exp(2*x)*math.sin(2*x) - 12*math.exp(2*x)*math.cos(2*x) - 9*math.exp(x)*math.sin(x) +12*math.exp(x)*math.cos(x) + 9)
#Método
i=0
while i<=N:
    P=PO-((f(PO)*g(PO))/((g(PO)**2)-(f(PO)*h(PO))))
#Evaluando
    if abs(P-PO)<TOL:
        print('La aproximación después de',i,'Iteraciones es P=',P)
        break
#Ahora para la siguiente iteración modificamos
    i=i+1
    PO=P
#Obtenemos
    if i<=N:
        print('Después de',i,'Iteraciones el punto obtenido es P=',P)
    else:
        print('El método falló después de',N,'Iteraciones')
# Out:
# ¿Cuál es la aproximación inicial?
# 3.5
# ¿Cuanta tolerancia?
# 0.0000000001
# ¿Cuantas iteraciones?
# 100
# Después de 1 Iteraciones el punto obtenido es P= 3.737540370312758
# Después de 2 Iteraciones el punto obtenido es P= 3.6598467232876732
# Después de 3 Iteraciones el punto obtenido es P= 3.6666197274414
# Después de 4 Iteraciones el punto obtenido es P= 3.666237537500099
# Después de 5 Iteraciones el punto obtenido es P= 3.6662586713441665
# Después de 6 Iteraciones el punto obtenido es P= 3.666257501767379
# Después de 7 Iteraciones el punto obtenido es P= 3.6662575664904495
# Después de 8 Iteraciones el punto obtenido es P= 3.6662575629087377
# Después de 9 Iteraciones el punto obtenido es P= 3.6662575631069467
# La aproximación después de 9 Iteraciones es P= 3.6662575630959773

# %%
#Program Metodo de NEWTON MODIFICADO
#ARELY ARTEAGA
#Program Método de NEWTON MODIFICADO del PROBLEMA 2(d)

#Ingresemos datos
print('¿Cuál es la aproximación inicial?')
PO=float(input())

print('¿Cuanta tolerancia?')
TOL=float(input())

print('¿Cuantas iteraciones?')
N=int(input())

#Definir la funcion
import math
def f(x):
    return  math.exp(3*x) - 27*pow(x,6) + 27*pow(x,4)*math.exp(x) - 9*pow(x,2)*math.exp(2*x)

#Definir primera derivada
def g(x):
    return 3*math.exp(3*x) - 18*pow(x,2)*math.exp(2*x) - 18*x*math.exp(2*x) + 27*pow(x,4)*math.exp(x) + 108*pow(x,3)*math.exp(x) -162*pow(x,5)

#Definir segunda derivada
def h(x):
    return  9*math.exp(3*x) + (-36*pow(x,2) - 72*x -18)*math.exp(2*x) + (27*pow(x,4) + 216*pow(x,3) + 324*pow(x,2))*math.exp(x) - 810*pow(x,4)
#Método
i=0
while i<=N:
    P=PO-((f(PO)*g(PO))/((g(PO)**2)-(f(PO)*h(PO))))
#Evaluando
    if abs(P-PO)<TOL:
        print('La aproximación después de',i,'Iteraciones es P=',P)
        break
#Ahora para la siguiente iteración modificamos
    i=i+1
    PO=P
#Obtenemos
    if i<=N:
        print('Después de',i,'Iteraciones el punto obtenido es P=',P)
    else:
        print('El método falló después de',N,'Iteraciones')
# Out:
# ¿Cuál es la aproximación inicial?
# 4
# ¿Cuanta tolerancia?
# 0.0000000001
# ¿Cuantas iteraciones?
# 100
# Después de 1 Iteraciones el punto obtenido es P= 3.6720356968912053
# Después de 2 Iteraciones el punto obtenido es P= 3.729580525560993
# Después de 3 Iteraciones el punto obtenido es P= 3.7330677236582193
# Después de 4 Iteraciones el punto obtenido es P= 3.733059957251739
# Después de 5 Iteraciones el punto obtenido es P= 3.733032441738644
# Después de 6 Iteraciones el punto obtenido es P= 3.733072095621122
# Después de 7 Iteraciones el punto obtenido es P= 3.7330690155892756
# Después de 8 Iteraciones el punto obtenido es P= 3.7330628415199647
# Después de 9 Iteraciones el punto obtenido es P= 3.73304551977263
# Después de 10 Iteraciones el punto obtenido es P= 3.7331378474692793
# Después de 11 Iteraciones el punto obtenido es P= 3.73308276561076
# La aproximación después de 11 Iteraciones es P= 3.73308276561076
