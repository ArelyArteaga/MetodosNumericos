# %%
 # Función para encontrar el término del producto
def proterm(i, value, x):
    pro = 1;
    for j in range(i):
        pro = pro * (value - x[j]);
    return pro;

# Función para calcular
# la tabla de diferencias dividida
def dividedDiffTable(x, y, n):

    for i in range(1, n):
        for j in range(n - i):
            y[j][i] = ((y[j][i - 1] - y[j + 1][i - 1]) /
                                     (x[j] - x[i + j]));
    return y;

# Función para aplicar la fórmula de
# formula divided difference
def applyFormula(value, x, y, n):

    sum = y[0][0];

    for i in range(1, n):
        sum = sum + (proterm(i, value, x) * y[0][i]);

    return sum;

# Función de visualización de la tabla de diferencias
# tabla de diferencias
def printDiffTable(y, n):

    for i in range(n):
        for j in range(n - i):
            print(round(y[i][j], 4), "\t",
                               end = " ");

        print("");

# Código del controlador

# número de entradas dadas
n = 4;
y = [[0 for i in range(10)]
        for j in range(10)];
x = [ 5, 6, 9, 11 ];

# y[][] se utiliza para la diferencia dividida
# tabla donde y[][0] se utiliza para la entrada
y[0][0] = 12;
y[1][0] = 13;
y[2][0] = 14;
y[3][0] = 16;

# calcular la tabla de diferencias divididas
y=dividedDiffTable(x, y, n);

# visualización de la tabla de diferencias divididas
printDiffTable(y, n);

# valor a interpolar
value = 7;

# imprimir el valor
print("\nValue at", value, "is",
        round(applyFormula(value, x, y, n), 2))
# Out:
# 12 	 1.0 	 -0.1667 	 0.05
# 13 	 0.3333 	 0.1333
# 14 	 1.0
# 16
#
# Value at 7 is 13.47

# %%
 # TAREA 6 DE MÉTDOS NUMERICOS POLINOMIOS DE NEWTON, DIFERENCIAS DIVIDIDAS
 # ARELY ARTEAGA
 # DIFERENCIAS DIVIDIDAS CÓDIGO PYTHON
def proterm(i, value, x):
    pro = 1;
    for j in range(i):
        pro = pro * (value - x[j]);
    return pro;

# Función para calcular
# la tabla de diferencias dividida
def dividedDiffTable(x, y, n):

    for i in range(1, n):
        for j in range(n - i):
            y[j][i] = ((y[j][i - 1] - y[j + 1][i - 1]) /
                                     (x[j] - x[i + j]));
    return y;

# Función para aplicar la fórmula de
# formula divided difference
def applyFormula(value, x, y, n):

    sum = y[0][0];

    for i in range(1, n):
        sum = sum + (proterm(i, value, x) * y[0][i]);

    return sum;

# Función de visualización de la tabla de diferencias
# tabla de diferencias
def printDiffTable(y, n):

    for i in range(n):
        for j in range(n - i):
            print(round(y[i][j], 4), "\t",
                               end = " ");

        print("");

# Código del controlador

# número de entradas dadas
n = 4;
y = [[0 for i in range(10)]
        for j in range(10)];
x = [ 0, 0.25, 0.5, 0.75];

# y[][] se utiliza para la diferencia dividida
# tabla donde y[][0] se utiliza para la entrada
y[0][0] = 1;
y[1][0] = 1.64872;
y[2][0] = 2.71828;
y[3][0] = 4.48169;


# calcular la tabla de diferencias divididas
y=dividedDiffTable(x, y, n);

# visualización de la tabla de diferencias divididas
printDiffTable(y, n);

# valor a interpolar
value = 0.43;

# imprimir el valor
print("\nValue at", value, "is",
        round(applyFormula(value, x, y, n), 2))
# Out:
# 1 	 2.5949 	 3.3667 	 2.9121
# 1.6487 	 4.2782 	 5.5508
# 2.7183 	 7.0536
# 4.4817
#
# Value at 0.43 is 2.36

# %%
# TAREA 6 DE MÉTDOS NUMERICOS POLINOMIOS DE NEWTON, DIFERENCIAS DIVIDIDAS
 # ARELY BETHZABE ARTEAGA LARA
 # DIFERENCIAS DIVIDIDAS CÓDIGO PYTHON
 # ACTIVIDAD 6: EJERCICIO 7

def proterm(i, value, x):
    pro = 1;
    for j in range(i):
        pro = pro * (value - x[j]);
    return pro;

# Función para calcular
# la tabla de diferencias dividida
def dividedDiffTable(x, y, n):

    for i in range(1, n):
        for j in range(n - i):
            y[j][i] = ((y[j][i - 1] - y[j + 1][i - 1]) /
                                     (x[j] - x[i + j]));
    return y;

# Función para aplicar la fórmula de
# formula divided difference
def applyFormula(value, x, y, n):

    sum = y[0][0];

    for i in range(1, n):
        sum = sum + (proterm(i, value, x) * y[0][i]);

    return sum;

# Función de visualización de la tabla de diferencias
# tabla de diferencias
def printDiffTable(y, n):

    for i in range(n):
        for j in range(n - i):
            print(round(y[i][j], 4), "\t",
                               end = " ");

        print("");

# Código del controlador

# número de entradas dadas
n = 4;
y = [[0 for i in range(10)]
        for j in range(10)];
x = [ -0.1, 0.0, 0.2, 0.3 ];

# y[][] se utiliza para la diferencia dividida
# tabla donde y[][0] se utiliza para la entrada
y[0][0] = 5.30000;
y[1][0] = 2.00000;
y[2][0] = 3.19000;
y[3][0] = 1.00000;


# calcular la tabla de diferencias divididas
y=dividedDiffTable(x, y, n);

# visualización de la tabla de diferencias divididas
printDiffTable(y, n);

# valor a interpolar
value = 0.35;

# imprimir el valor
print("\nValue at", value, "is",
        round(applyFormula(value, x, y, n), 2))
# Out:
# 5.3 	 -33.0 	 129.8333 	 -556.6667
# 2.0 	 5.95 	 -92.8333
# 3.19 	 -21.9
# 1.0
#
# Value at 0.35 is -2.25
